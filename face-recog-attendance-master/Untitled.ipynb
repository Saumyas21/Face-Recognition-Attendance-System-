# %%
pip install dlib==19.24.1
# Out:
# Collecting dlib==19.24.1
#   Using cached dlib-19.24.1.tar.gz (3.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib
#   Running setup.py install for dlib: started
#   Running setup.py install for dlib: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [68 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         if LooseVersion(cmake_version) < '3.1.0':
#       Building extension for Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=C:\Users\saumy\Downloads\anaconda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\build\lib.win-amd64-cpython-39 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 222, in <module>
#           setup(
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#           self.run_command('build')
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 134, in run
#           self.build_extension(ext)
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 171, in build_extension
#           subprocess.check_call(cmake_setup, cwd=build_folder)
#         File "C:\Users\saumy\Downloads\anaconda\lib\subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=C:\\Users\\saumy\\Downloads\\anaconda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for dlib did not run successfully.
#   │ exit code: 1
#   ╰─> [83 lines of output]
#       running install
#       C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#       !!
#
#               ********************************************************************************
#               Please avoid running ``setup.py`` directly.
#               Instead, use pypa/build, pypa/installer, pypa/build or
#               other standards-based tools.
#
#               See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#               ********************************************************************************
#
#       !!
#         self.initialize_options()
#       running build
#       running build_py
#       running build_ext
#       C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         if LooseVersion(cmake_version) < '3.1.0':
#       Building extension for Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=C:\Users\saumy\Downloads\anaconda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\build\lib.win-amd64-cpython-39 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 222, in <module>
#           setup(
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\command\install.py", line 74, in run
#           return orig.install.run(self)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\install.py", line 697, in run
#           self.run_command('build')
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 134, in run
#           self.build_extension(ext)
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-7ke6dd0l\dlib_7b3f7166a2ba41c8a368ccb7b749c114\setup.py", line 171, in build_extension
#           subprocess.check_call(cmake_setup, cwd=build_folder)
#         File "C:\Users\saumy\Downloads\anaconda\lib\subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=C:\\Users\\saumy\\Downloads\\anaconda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-7ke6dd0l\\dlib_7b3f7166a2ba41c8a368ccb7b749c114\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> dlib
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: Pillow in c:\users\saumy\downloads\anaconda\lib\site-packages (from face_recognition) (9.2.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\saumy\downloads\anaconda\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: numpy in c:\users\saumy\downloads\anaconda\lib\site-packages (from face_recognition) (1.21.5)
# Collecting dlib>=19.7
#   Using cached dlib-19.24.1.tar.gz (3.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Click>=6.0 in c:\users\saumy\downloads\anaconda\lib\site-packages (from face_recognition) (8.0.4)
# Requirement already satisfied: colorama in c:\users\saumy\downloads\anaconda\lib\site-packages (from Click>=6.0->face_recognition) (0.4.5)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib, face_recognition
#   Running setup.py install for dlib: started
#   Running setup.py install for dlib: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [68 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         if LooseVersion(cmake_version) < '3.1.0':
#       Building extension for Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=C:\Users\saumy\Downloads\anaconda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\build\lib.win-amd64-cpython-39 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 222, in <module>
#           setup(
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#           self.run_command('build')
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 134, in run
#           self.build_extension(ext)
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 171, in build_extension
#           subprocess.check_call(cmake_setup, cwd=build_folder)
#         File "C:\Users\saumy\Downloads\anaconda\lib\subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=C:\\Users\\saumy\\Downloads\\anaconda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for dlib did not run successfully.
#   │ exit code: 1
#   ╰─> [83 lines of output]
#       running install
#       C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#       !!
#
#               ********************************************************************************
#               Please avoid running ``setup.py`` directly.
#               Instead, use pypa/build, pypa/installer, pypa/build or
#               other standards-based tools.
#
#               See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#               ********************************************************************************
#
#       !!
#         self.initialize_options()
#       running build
#       running build_py
#       running build_ext
#       C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         if LooseVersion(cmake_version) < '3.1.0':
#       Building extension for Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
#       Invoking CMake setup: 'cmake C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=C:\Users\saumy\Downloads\anaconda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\build\lib.win-amd64-cpython-39 -A x64'
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:5 (message):
#
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#         You must use Visual Studio to build a python extension on windows.  If you
#         are getting this error it means you have not installed Visual C++.  Note
#         that there are many flavors of Visual Studio, like Visual Studio for C#
#         development.  You need to install Visual Studio for C++.
#
#
#         !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 222, in <module>
#           setup(
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#           return run_commands(dist)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#           dist.run_commands()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\command\install.py", line 74, in run
#           return orig.install.run(self)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\install.py", line 697, in run
#           self.run_command('build')
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "C:\Users\saumy\Downloads\anaconda\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 134, in run
#           self.build_extension(ext)
#         File "C:\Users\saumy\AppData\Local\Temp\pip-install-9ucffz_1\dlib_272f9710072d44969dc97d7513527a81\setup.py", line 171, in build_extension
#           subprocess.check_call(cmake_setup, cwd=build_folder)
#         File "C:\Users\saumy\Downloads\anaconda\lib\subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=C:\\Users\\saumy\\Downloads\\anaconda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\saumy\\AppData\\Local\\Temp\\pip-install-9ucffz_1\\dlib_272f9710072d44969dc97d7513527a81\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> dlib
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import cv2
import numpy as np
import face_recognition
import os
from datetime import datetime

#Loading images using path
path = 'Images'
images = []
names = []
List = os.listdir(path)
#print(List)

for name in List:
    img = cv2.imread(f'{path}/{name}')
    images.append(img)
    names.append(os.path.splitext(name)[0])

#print(names)

#Function to find encodings for all images in directory

def encode(images):
    encode_list = []
    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encodeImg = face_recognition.face_encodings(img)[0]
        encode_list.append(encodeImg)
    return encode_list

def record_attendance(name):
    with open('attendancelist.csv', 'r+') as file:
        List = file.readlines()
        namelist = []

        for line in List:
            record = line.split(',')
            namelist.append(record[0])
        if name not in namelist:
            now = datetime.now()
            dt = now.strftime('%H:%M:%S')
            file.writelines(f'\n{name},{dt}')

print("Encoding Images...")
encodeList = encode(images)
print("Encoding Completed.")

#Initializing webcam
cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    #Reducing size of real-time image to 1/4th
    imgResize = cv2.resize(img, (0,0), None, 0.25, 0.25)
    imgResize = cv2.cvtColor(imgResize, cv2.COLOR_BGR2RGB)

    # Finding face in current frame
    face = face_recognition.face_locations(imgResize)
    # Encode detected face
    encodeImg = face_recognition.face_encodings(imgResize, face)

    #Finding matches with existing images
    for encodecurr, loc in zip(encodeImg, face):
        match = face_recognition.compare_faces(encodeList, encodecurr)
        faceDist = face_recognition.face_distance(encodeList, encodecurr)
        print(faceDist)
        #Lowest distance will be best match
        index_BestMatch = np.argmin(faceDist)

        if match[index_BestMatch]:
            name = names[index_BestMatch]
            y1,x2,y2,x1 = loc
            #Retaining original image size for rectangle location
            y1,x2,y2,x1 = y1*4, x2*4, y2*4, x1*4
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,255),1)
            cv2.rectangle(img,(x1,y2-30),(x2,y2), (255,0,255), cv2.FILLED)
            cv2.putText(img, name, (x1+8, y2-10), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0,255,255),2)
            record_attendance(name)

    cv2.imshow('Webcam', img)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21096\4236744526.py in <module>
#       1 import cv2
#       2 import numpy as np
# ----> 3 import face_recognition
#       4 import os
#       5 from datetime import datetime
#
# ModuleNotFoundError: No module named 'face_recognition'
